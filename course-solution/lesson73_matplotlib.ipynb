# %% [markdown]
# # Matplotlib
#
# Visualisierungen in Python mit Matplotlib:
#
# - Matplotlib ist die Standardbibliothek für Visualisierungen in Python.
# - Man kann mit wenigen Befehlen Diagramme erstellen: Linien, Balken, Scatterplots usw.
# - Häufig wird das Untermodul `pyplot` verwendet (ähnlich wie in MATLAB).

# %% [markdown]
# ## Grundlagen

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, label="y = x²")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grundlegendes Liniendiagramm")
plt.legend()
plt.show()

# %% [markdown]
# ## Liniendiagramm einer Funktion

# %%
import numpy as np

x = np.linspace(-5, 5, 100)
y = x**2

plt.plot(x, y, label="y = x²", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Quadratfunktion")
plt.legend()
plt.show()

# %% [markdown]
# ## Mehrere Linien im gleichen Diagramm

# %%
x = np.linspace(0, 2*np.pi, 200)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="sin(x)", color="red")
plt.plot(x, y2, label="cos(x)", color="green")
plt.xlabel("x")
plt.ylabel("Wert")
plt.title("Sinus und Cosinus")
plt.legend()
plt.show()

# %% [markdown]
# ## Balkendiagramm

# %%
namen = ["Anna", "Ben", "Clara", "David"]
alter = [23, 35, 29, 40]

plt.bar(namen, alter, color="orange")
plt.xlabel("Name")
plt.ylabel("Alter")
plt.title("Alter der Personen")
plt.show()

# %% [markdown]
# ## Histogramm

# %%
daten = np.random.randn(1000)  # 1000 normalverteilte Zufallszahlen

plt.hist(daten, bins=30, color="skyblue", edgecolor="black")
plt.title("Histogramm der Daten")
plt.xlabel("Werte")
plt.ylabel("Häufigkeit")
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, alpha=0.7, c="red")
plt.title("Scatterplot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Subplots

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(x, y1, "b")
axs[0].set_title("sin(x)")

axs[1].plot(x, y2, "g")
axs[1].set_title("cos(x)")

plt.suptitle("Sinus und Cosinus in Subplots")
plt.show()

# %% [markdown]
# # Aufgaben

# %% [markdown]
# ## Barchart Noten
#
# - Erstelle eine Liste von 5 Schüler Namen.
# - Erstelle eine Liste mit den Noten der obigen Schüler.
# - Erstelle ein Balkendiagramm mit den Noten der 5 Schüler.
# - Skaliere die Y-Achse für die Notenskala 0-6 mit dem Befehl `plt.ylim(0,6)`
# - Beschrifte das Diagramm mit Titel, X und Y Achse.

# %%
schueler = ["Anna", "Ben", "Clara", "David", "Eva"]
noten = [5.0, 4.5, 5.5, 3.5, 4.0]  # Beispielnoten

plt.bar(schueler, noten, color="skyblue", edgecolor="black")
plt.xlabel("Schüler")
plt.ylabel("Note")
plt.title("Notenübersicht")
plt.ylim(0, 6)  # y-Achse für Notenskala (0–6)
plt.show()

# %% [markdown]
# ## Plot Hoch 3
#
# - Zeichne ein Plot mit der Funktion `y = x³` für den Zahlenberich `x = -5 … 5`.
# - Beschreibe den Plot mit Titel, X, und Y Achse.
# - Erstelle eine Legende mit dem Befehl `plt.legend()`
#
# Tipps:
# - Die Werte für die X-Achse können mit den folgenden NumPy Befehl erzeugt werden:
#   ```
#   np.linspace(-5, 5, 100)
#   ```
# - Füge mit den folgenden Befehlen eine horizontale und vertikale Hilfslinie ein:
#   ```
#   plt.axhline(0, color="black", linewidth=0.8)  # x-Achse
#   plt.axvline(0, color="black", linewidth=0.8)  # y-Achse
#   ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = x**3

plt.plot(x, y, label="y = x³", color="blue")

plt.axhline(0, color="black", linewidth=0.8)  # x-Achse
plt.axvline(0, color="black", linewidth=0.8)  # y-Achse

plt.title("Funktion y = x³")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

plt.show()
